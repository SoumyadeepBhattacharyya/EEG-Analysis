# %% [markdown]
# # Project Name - EEG Analysis

# %% [markdown]
# **Project Type** - Biology / Neuroscience

# %% [markdown]
# **Project Prepared By** - Soumyadeep Bhattacharyya

# %% [markdown]
# # Project Summary

# %% [markdown]
# This project focuses on the analysis of Electroencephalogram (EEG) brain signals to understand cognitive behavior, mental workload, fatigue patterns, and neural responses across different subject groups. The EEG dataset contains high-frequency time-series data along with behavioral and demographic attributes such as Diagnosis, Sex, Session, Events, EEG Power Bands, SNR, Fatigue Levels, Engagement Index, and more.
#
# Python and R were used together to build a complete data analysis pipeline, covering data cleaning, feature extraction, visualization, statistical analysis, and interpretation.
#
# # **Key Objectives**
#
# 1. Clean and preprocess EEG data (handle missing values, outliers, encoding scaling)
#
# 2. Extract meaningful EEG features (Alpha, Beta, Theta, Gamma, SNR)
#
# 3. Analyze cognitive states, neural activity patterns, and fatigue
#
# 4. Compare EEG behavior across Diagnosis, Sex, and Session
#
# 5. Visualize distributions and relationships using Python, R, and Plotly (interactive)
#
# 6. Provide clinically meaningful insights for neuroscience applications
#
# # **Approach & Methodology**
#
# **1. Data Preprocessing**
#
# 1.1. Handling missing values using median/mode imputation
#
# 1.2. Outlier treatment with IQR method
#
# 1.3. Encoding categorical attributes (Diagnosis, Sex, Event)
#
# 1.4. Scaling numerical EEG features
#
# 1.5. R used for statistical validation and visualization
#
# **2. Feature Engineering**
#
# 2.1. Extracted EEG-related features such as:
#
# 2.2. Alpha, Beta, Theta, Gamma Power
#
# 2.3. SNR (Signal-to-Noise Ratio)
#
# 2.4. Fatigue Level
#
# 2.5. Engagement Index
#
# 2.6. Channel Difference & Artifact Score
#
# **3. Exploratory Data Analysis**
#
# Performed 12+ visual analyses, including:
#
# 3.1. Distribution plots for EEG power bands
#
# 3.2. Engagement Index trend analysis
#
# 3.3. Diagnosis-wise boxplots
#
# 3.4. EEG Channel difference assessment
#
# 3.5. Correlation heatmaps
#
# 3.6. Interactive scatter plots (Plotly)
#
# 3.7. Pairplots to understand inter-feature relationships
#
# 3.8. Fatigue distribution
#
# 3.9. Event-wise EEG changes
#
# **4. Tools & Technologies**
#
# 4.1. Python: pandas, seaborn, matplotlib, plotly, numpy
#
# 4.2. R: ggplot2, ggpairs, plotly, dplyr
#
#
# # **Project Insights**
#
# **1. Alpha, Beta, Theta & Gamma Power Distributions**
#
# •	Alpha and Theta power show higher variance, indicating subjects may be in mixed states of relaxation, attention, and drowsiness.
#
# •	Beta and Gamma power appear more concentrated for most subjects, suggesting consistent cognitive activity across trials.
#
# **2. Diagnosis-wise EEG Differences**
#
# •	Subjects with Cognitive Disorder category show:
#
# o	Lower Alpha power (difficulty relaxing)
# o	Higher Theta in some cases (inattention / fatigue)
# o	Slightly lower SNR, meaning noisier EEG signals
#
# •	Healthy subjects show stronger Gamma activity, indicating better cognitive integration.
#
# **3. EEG Channel Difference (EEG_Ch1 vs EEG_Ch2)**
#
# •	Channel differences remain stable for most subjects → indicates good electrode placement.
#
# •	A few subjects show unusually high difference → likely artifact contamination.
#
# **4. Fatigue Level Pattern**
#
# •	The distribution indicates:
#
# o	Most subjects fall in moderate fatigue range.
# o	A tail of high fatigue values points to extended task duration or cognitive overload.
#
# **5. Engagement Index Over Time**
#
# •	Initial high engagement gradually dips → indicates:
#
# o	Reduced attention as trial progresses.
# o	Possible task monotony or mental fatigue.
#
# •	Sudden spikes in some cases → possibly stimulus events or artifact moments.
#
# **6. Cognitive Load vs Sex**
#
# •	Cognitive load seems slightly higher in females (if seen in your plot),
# but the difference is not extremely large.
#
# •	High variability indicates cognitive load is influenced more by task type than by biological sex.
#
# **7. SNR vs Gamma Power**
#
# •	Higher SNR is correlated with higher GammaPower → meaning:
#
# o	Cleaner EEG signals produce stronger high-frequency information.
#
# •	Low SNR cluster likely represents movement artifacts or electrode noise.
#
# **8. Event-Wise Differences**
#
# •	Trials where “Start”, “Task”, or “Stimulus” occurred show:
#
# o	Higher Beta/Gamma (active cognitive phase)
# o	Lower Alpha (reduced relaxation)
#
# **9. Artifact Score**
#
# •	Subjects with high artifact scores correlate with:
#
# o	Lower SNR
# o	Higher Channel differences
#
# •	Suggests eye blinks, muscle noise, or poor electrode contact.
#
# # **Recommendations**
#
# **1. Alpha, Beta, Theta & Gamma Power Distributions**
#
# •	Apply state-specific segmentation (rest vs task) to better isolate patterns.
#
# •	Use band-specific normalization to reduce subject-to-subject variability.
#
# •	Perform ICA or advanced filtering to ensure the high variance isn’t caused by artifacts.
#
# **2. Diagnosis-wise EEG Differences**
#
# •	Integrate Alpha-Theta ratio as an early diagnostic feature.
#
# •	Use SNR thresholding before feature extraction to ensure cleaner signals.
#
# •	Consider building a classification model (e.g., Random Forest, SVM) to differentiate diagnosis groups using these biomarkers.
#
# **3. EEG Channel Difference (EEG_Ch1 vs EEG_Ch2)**
#
# •	Apply automatic channel quality checks before analysis.
#
# •	Flag subjects with high ChannelDiff values for manual inspection.
#
# •	Consider using re-referencing techniques (CAR, Laplacian) to stabilize channel differences.
#
# **4. Fatigue Level Pattern**
#
# •	Use task break indicators for subjects with consistently high fatigue levels.
#
# •	Apply sliding-window analysis to estimate real-time fatigue trends.
#
# •	Build a fatigue prediction model using Theta/Alpha ratio and Engagement Index.
#
# **5. Engagement Index Over Time**
#
# •	Implement micro-break suggestions during long tasks.
#
# •	Use rising and falling engagement patterns as features in cognitive load prediction.
#
# •	Evaluate engagement alongside event markers to identify exact causes of dips.
#
# **6. Cognitive Load vs Sex**
#
# •	Analyze cognitive load per task type, not just sex, to avoid bias.
#
# •	Include more demographic factors (age, diagnosis, education level) in modeling.
#
# •	Use cognitive load as a personalized parameter rather than a group-level one.
#
# **7. SNR vs Gamma Power**
#
# •	Use SNR-based weighting when calculating GammaPower features.
#
# •	Apply artifact removal (ICA, notch filters) to improve SNR before analysis.
#
# •	Skip low-SNR segments in machine learning models to avoid performance drop.
#
# **8. Event-Wise Differences**
#
# •	Segment and analyze EEG event-wise instead of full sequence processing.
#
# •	Use Beta/Gamma features for task engagement or workload detection.
#
# •	Build event-specific feature summaries for clinicians.
#
# **9. Artifact Score**
#
# •	Set artifact score cut-off thresholds to remove noisy segments.
#
# •	Apply automatic artifact rejection tools (e.g., Wavelet Denoising, ASR).
#
# •	Re-train your models with and without artifact-heavy recordings to test performance.
#
#
# # **Conclusion**
#
# This project demonstrates how EEG signals can be used to evaluate cognitive function, fatigue, diagnosis differences, and signal quality. By integrating Python, R the workflow becomes robust, reproducible, and clinically valuable.
#
# The insights discovered can help neuroscientists, psychologists, and clinicians better understand brain activity patterns, detect anomalies, assess treatment progress, and design cognitive experiments.

# %% [markdown]
# # Coding section

# %% [markdown]
# **1. Know your data**

# %% [markdown]
# Import Libraries

# %%
#Import Libraries

import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

import missingno as msno

import warnings

warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler

from sklearn.decomposition import PCA

# %% [markdown]
# Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read the excel file
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/eeg_dataset_advanced.csv.xlsx")
df.head()
# Out:
#   SubjectID  Age Sex Diagnosis   Session  Sample  EEG_Ch1  EEG_Ch2     Event  \
# 0  SUBJ_048   38   M  Epilepsy  Baseline       1   4.3558   0.2739  Stimulus
# 1  SUBJ_005   34   F  Epilepsy  Baseline       2   4.2919   3.3674  Artifact
# 2  SUBJ_026   27   M   Control      Task       3  14.0861   7.8877      Rest
# 3  SUBJ_004   27   M       MCI  PostTask       4  10.8692   9.2690      Rest
# 4  SUBJ_020   32   F       MCI  PostTask       5  14.3835  15.3649  Stimulus
#
#    AlphaPower  BetaPower  ThetaPower  GammaPower    SNR  ChannelDiff  \
# 0   37.880530  32.974424   37.352598   16.324296  15.03       4.0819
# 1   45.080328  30.771919   50.689475   21.352078  11.68       0.9245
# 2   41.263539  40.021418   58.140226   23.119613  10.55       6.1984
# 3   30.856345  26.931764   42.997025   21.232257   7.71       1.6002
# 4   55.868528  23.924518   32.559707   22.478821  24.70      -0.9814
#
#    ArtifactScore  EngagementIndex  FatigueLevel  CognitiveLoad
# 0       0.322342            0.848         1.099          0.420
# 1       0.766429            0.668         1.595          0.463
# 2       0.267192            0.947         1.417          0.547
# 3       0.142956            0.845         1.539          0.667
# 4       0.395131            0.421         1.306          0.395

# %%
# Copying the Dataset for Cleaning
df_clean = df.copy()

print(df.columns.tolist())
print(df_clean.columns.tolist())
len(df_clean.columns.tolist())
# Out:
# ['SubjectID', 'Age', 'Sex', 'Diagnosis', 'Session', 'Sample', 'EEG_Ch1', 'EEG_Ch2', 'Event', 'AlphaPower', 'BetaPower', 'ThetaPower', 'GammaPower', 'SNR', 'ChannelDiff', 'ArtifactScore', 'EngagementIndex', 'FatigueLevel', 'CognitiveLoad']
# ['SubjectID', 'Age', 'Sex', 'Diagnosis', 'Session', 'Sample', 'EEG_Ch1', 'EEG_Ch2', 'Event', 'AlphaPower', 'BetaPower', 'ThetaPower', 'GammaPower', 'SNR', 'ChannelDiff', 'ArtifactScore', 'EngagementIndex', 'FatigueLevel', 'CognitiveLoad']
# 19

# %%
# Dataset First Look
print("First 5 rows of the dataset:\n")
df_clean.head()
# Out:
# First 5 rows of the dataset:
#   SubjectID  Age Sex Diagnosis   Session  Sample  EEG_Ch1  EEG_Ch2     Event  \
# 0  SUBJ_048   38   M  Epilepsy  Baseline       1   4.3558   0.2739  Stimulus
# 1  SUBJ_005   34   F  Epilepsy  Baseline       2   4.2919   3.3674  Artifact
# 2  SUBJ_026   27   M   Control      Task       3  14.0861   7.8877      Rest
# 3  SUBJ_004   27   M       MCI  PostTask       4  10.8692   9.2690      Rest
# 4  SUBJ_020   32   F       MCI  PostTask       5  14.3835  15.3649  Stimulus
#
#    AlphaPower  BetaPower  ThetaPower  GammaPower    SNR  ChannelDiff  \
# 0   37.880530  32.974424   37.352598   16.324296  15.03       4.0819
# 1   45.080328  30.771919   50.689475   21.352078  11.68       0.9245
# 2   41.263539  40.021418   58.140226   23.119613  10.55       6.1984
# 3   30.856345  26.931764   42.997025   21.232257   7.71       1.6002
# 4   55.868528  23.924518   32.559707   22.478821  24.70      -0.9814
#
#    ArtifactScore  EngagementIndex  FatigueLevel  CognitiveLoad
# 0       0.322342            0.848         1.099          0.420
# 1       0.766429            0.668         1.595          0.463
# 2       0.267192            0.947         1.417          0.547
# 3       0.142956            0.845         1.539          0.667
# 4       0.395131            0.421         1.306          0.395

# %% [markdown]
# Dataset Rows & Columns Count

# %%
num_rows, num_columns = df_clean.shape

print (f'Number of rows: {num_rows}')
print(f'Number of columns: {num_columns}')
# Out:
# Number of rows: 2000
# Number of columns: 19

# %% [markdown]
# Dataset Information

# %%
# Dataset Info
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SubjectID        2000 non-null   object
#  1   Age              2000 non-null   int64
#  2   Sex              2000 non-null   object
#  3   Diagnosis        2000 non-null   object
#  4   Session          2000 non-null   object
#  5   Sample           2000 non-null   int64
#  6   EEG_Ch1          2000 non-null   float64
#  7   EEG_Ch2          2000 non-null   float64
#  8   Event            2000 non-null   object
#  9   AlphaPower       2000 non-null   float64
#  10  BetaPower        2000 non-null   float64
#  11  ThetaPower       2000 non-null   float64
#  12  GammaPower       2000 non-null   float64
#  13  SNR              2000 non-null   float64
#  14  ChannelDiff      2000 non-null   float64
#  15  ArtifactScore    2000 non-null   float64
#  16  EngagementIndex  2000 non-null   float64
#  17  FatigueLevel     2000 non-null   float64
#  18  CognitiveLoad    2000 non-null   float64
# dtypes: float64(12), int64(2), object(5)
# memory usage: 297.0+ KB

# %% [markdown]
# Duplicate Values

# %%
# Dataset Duplicate Value Count
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Missing Values / Null Values

# %%
#Missing Values / Null Values
df_clean.isnull().sum()
# Out:
# SubjectID          0
# Age                0
# Sex                0
# Diagnosis          0
# Session            0
# Sample             0
# EEG_Ch1            0
# EEG_Ch2            0
# Event              0
# AlphaPower         0
# BetaPower          0
# ThetaPower         0
# GammaPower         0
# SNR                0
# ChannelDiff        0
# ArtifactScore      0
# EngagementIndex    0
# FatigueLevel       0
# CognitiveLoad      0
# dtype: int64

# %% [markdown]
# Visualising the missing values

# %%
# Visualising the missing values
# Missingo Matrix
plt.figure(figsize=(12,6))
msno.matrix(df)
plt.show()

# %%
# Missing Value Heatmap
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# What did you know about your Dataset ?

# %% [markdown]
# 2. Understanding the Variables

# %%
#Dataset Columns

print("Columns Present in the Dataset:\n")
print(df_clean.columns)

print("\n Data types of the colums of the dataset: ")
print(df_clean.dtypes)
# Out:
# Columns Present in the Dataset:
#
# Index(['SubjectID', 'Age', 'Sex', 'Diagnosis', 'Session', 'Sample', 'EEG_Ch1',
#        'EEG_Ch2', 'Event', 'AlphaPower', 'BetaPower', 'ThetaPower',
#        'GammaPower', 'SNR', 'ChannelDiff', 'ArtifactScore', 'EngagementIndex',
#        'FatigueLevel', 'CognitiveLoad'],
#       dtype='object')
#
#  Data types of the colums of the dataset:
# SubjectID           object
# Age                  int64
# Sex                 object
# Diagnosis           object
# Session             object
# Sample               int64
# EEG_Ch1            float64
# EEG_Ch2            float64
# Event               object
# AlphaPower         float64
# BetaPower          float64
# ThetaPower         float64
# GammaPower         float64
# SNR                float64
# ChannelDiff        float64
# ArtifactScore      float64
# EngagementIndex    float64
# FatigueLevel       float64
# CognitiveLoad      float64
# dtype: object

# %% [markdown]
# Dataset Describe

# %%
print("Description of the Dataset")
df_clean.describe()
# Out:
# Description of the Dataset
#                Age       Sample      EEG_Ch1      EEG_Ch2   AlphaPower  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     32.519000  1000.500000    -0.168551     0.084546    50.188416
# std      10.332232   577.494589    14.389575    10.727177     9.909619
# min      11.000000     1.000000   -26.954100   -20.875700    17.413947
# 25%      25.000000   500.750000   -13.867500   -10.189550    43.410292
# 50%      32.000000  1000.500000    -0.288300     0.258550    50.206563
# 75%      38.000000  1500.250000    13.582425    10.152875    57.171049
# max      58.000000  2000.000000    28.372800    21.707600    82.676789
#
#          BetaPower   ThetaPower   GammaPower          SNR  ChannelDiff  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     30.042788    39.961532    19.971973    15.210850    -0.253098
# std       7.977156     9.072011     4.946701     5.794459    18.079628
# min       3.704808    10.362590     4.549559     5.000000   -40.785000
# 25%      24.573239    33.997451    16.616978    10.187500   -13.149800
# 50%      30.168038    39.897099    20.119323    15.340000    -0.583500
# 75%      35.425158    46.127062    23.267793    20.235000    12.598925
# max      57.227997    69.499386    38.008782    24.990000    43.433900
#
#        ArtifactScore  EngagementIndex  FatigueLevel  CognitiveLoad
# count    2000.000000      2000.000000   2000.000000    2000.000000
# mean        0.366582         0.611052      1.400022       0.406621
# std         0.275112         0.212633      0.613231       0.135319
# min         0.000320         0.058000      0.278000       0.077000
# 25%         0.151078         0.462750      1.040000       0.310000
# 50%         0.308815         0.594000      1.286000       0.394000
# 75%         0.465427         0.730000      1.610250       0.480000
# max         0.999596         2.150000      7.007000       1.332000

# %% [markdown]
# Variables Description

# %% [markdown]
# Check Unique Values for each Variables

# %%
# Check Unique Values for each Variables
print("Unique values in each Columns of the Dataset: \n")
print(df_clean.nunique())
# Out:
# Unique values in each Columns of the Dataset:
#
# SubjectID            50
# Age                  29
# Sex                   2
# Diagnosis             3
# Session               3
# Sample             2000
# EEG_Ch1            1995
# EEG_Ch2            1989
# Event                 5
# AlphaPower         2000
# BetaPower          2000
# ThetaPower         2000
# GammaPower         2000
# SNR                1278
# ChannelDiff        1995
# ArtifactScore      2000
# EngagementIndex     732
# FatigueLevel       1172
# CognitiveLoad       561
# dtype: int64

# %% [markdown]
# # 3. Data Wragling

# %% [markdown]
# 1. Remove Exact Duplicates

# %%
print("Checking for duplicate rows...\n")
print("Duplicates found: ", df_clean.duplicated().sum())

df_clean = df_clean.drop_duplicates()
print("Shape after removing duplicates:", df_clean.shape)
# Out:
# Checking for duplicate rows...
#
# Duplicates found:  0
# Shape after removing duplicates: (2000, 19)

# %% [markdown]
# 2. Detect & Treat Outliers

# %%
print("Detecting and treating outliers...\n")

numeric_cols = df_clean.select_dtypes(include= [np.number]).columns.tolist()
for col in numeric_cols:
       Q1 = df_clean[col].quantile(0.25)
       Q3 = df_clean[col].quantile(0.75)

       IQR = Q3 - Q1
       lower = Q1 - 1.5 * IQR
       upper = Q3 + 1.5 * IQR
       median_val = df_clean[col].median()

       df_clean.loc[df_clean[col] < lower, col] = median_val
       df_clean.loc[df_clean[col] > upper, col] = median_val
# Out:
# Detecting and treating outliers...

# %%
#Visualisation outliers using box-plot
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

plt.figure(figsize=(14,6))
df[numeric_cols].boxplot()
plt.xticks(rotation=45)
plt.title("Boxplots for All Numeric Columns")
plt.show()

# %% [markdown]
# 3. Scaling & normalization

# %%
print("Scaling numerical features...\n")
import numpy as np
numeric_cols = df_clean.select_dtypes(include= [np.number]).columns.tolist()

scale_cols =[col for col in numeric_cols if col not in ["Age","Sample"]]
scaler= MinMaxScaler()
df_clean[scale_cols] = scaler.fit_transform(df_clean[scale_cols])
# Out:
# Scaling numerical features...

# %% [markdown]
# 4.ENCODING CATEGORICAL DATA

# %%
df_clean = df.copy()

print("Encoding categorical features...")

from sklearn.preprocessing import LabelEncoder

# Step 1: find object columns
categorical_cols = df_clean.select_dtypes(include=['object']).columns.tolist()

# Step 2: Label encode them (NO ONE-HOT)
le = LabelEncoder()

for col in categorical_cols:
    df_clean[col] = le.fit_transform(df_clean[col])

print("Encoding complete.")
print(df_clean.shape)
# Out:
# Encoding categorical features...
# Encoding complete.
# (2000, 19)

# %% [markdown]
# 5. Feature Engineering

# %%
#Age group (Young, Middle-aged, Senior)

df_clean["age_group"] = pd.cut(
  df_clean["Age"] * (df_clean["Age"].max() - df_clean["Age"].min()) + df_clean["Age"].min(),
  bins=[0, 40, 55, 100], labels=["Young", "Middle-aged", "Senior"]

)

df_clean = pd.get_dummies(df_clean, columns=["age_group"], drop_first=True)
print("New Features Added!")
# Out:
# New Features Added!

# %% [markdown]
# Drop Unnecessary Column

# %%
df_clean = df_clean.drop(columns=["Sample"])

# %% [markdown]
# Final Processed Dataset

# %%
print("Final dataset shape:", df_clean.shape)
df_clean.head()
# Out:
# Final dataset shape: (2000, 20)
#    SubjectID  Age  Sex  Diagnosis  Session  EEG_Ch1  EEG_Ch2  Event  \
# 0         47   38    1          1        0   4.3558   0.2739      4
# 1          4   34    0          1        0   4.2919   3.3674      0
# 2         25   27    1          0        2  14.0861   7.8877      3
# 3          3   27    1          2        1  10.8692   9.2690      3
# 4         19   32    0          2        1  14.3835  15.3649      4
#
#    AlphaPower  BetaPower  ThetaPower  GammaPower    SNR  ChannelDiff  \
# 0   37.880530  32.974424   37.352598   16.324296  15.03       4.0819
# 1   45.080328  30.771919   50.689475   21.352078  11.68       0.9245
# 2   41.263539  40.021418   58.140226   23.119613  10.55       6.1984
# 3   30.856345  26.931764   42.997025   21.232257   7.71       1.6002
# 4   55.868528  23.924518   32.559707   22.478821  24.70      -0.9814
#
#    ArtifactScore  EngagementIndex  FatigueLevel  CognitiveLoad  \
# 0       0.322342            0.848         1.099          0.420
# 1       0.766429            0.668         1.595          0.463
# 2       0.267192            0.947         1.417          0.547
# 3       0.142956            0.845         1.539          0.667
# 4       0.395131            0.421         1.306          0.395
#
#    age_group_Middle-aged  age_group_Senior
# 0                  False             False
# 1                  False             False
# 2                  False             False
# 3                  False             False
# 4                  False             False

# %%
print("Preparing target and feature sets...\n")



#  Select TARGET variable
y = df_clean['Diagnosis']   # Target column

# Feature set = remove target
X = df_clean.drop('Diagnosis', axis=1)

print("Shape of features (X) before processing:", X.shape)
print("\nTarget (y) distribution:")
display(y.value_counts())

print("\nPreview of X:")
display(X.head())

print("\nPreview of y:")
display(y.head())
# Out:
# Preparing target and feature sets...
#
# Shape of features (X) before processing: (2000, 18)
#
# Target (y) distribution:
# Diagnosis
# MCI         973
# Control     557
# Epilepsy    470
# Name: count, dtype: int64
# Preview of X:
#   SubjectID  Age Sex   Session  Sample  EEG_Ch1  EEG_Ch2     Event  \
# 0  SUBJ_048   38   M  Baseline       1   4.3558   0.2739  Stimulus
# 1  SUBJ_005   34   F  Baseline       2   4.2919   3.3674  Artifact
# 2  SUBJ_026   27   M      Task       3  14.0861   7.8877      Rest
# 3  SUBJ_004   27   M  PostTask       4  10.8692   9.2690      Rest
# 4  SUBJ_020   32   F  PostTask       5  14.3835  15.3649  Stimulus
#
#    AlphaPower  BetaPower  ThetaPower  GammaPower    SNR  ChannelDiff  \
# 0   37.880530  32.974424   37.352598   16.324296  15.03       4.0819
# 1   45.080328  30.771919   50.689475   21.352078  11.68       0.9245
# 2   41.263539  40.021418   58.140226   23.119613  10.55       6.1984
# 3   30.856345  26.931764   42.997025   21.232257   7.71       1.6002
# 4   55.868528  23.924518   32.559707   22.478821  24.70      -0.9814
#
#    ArtifactScore  EngagementIndex  FatigueLevel  CognitiveLoad
# 0       0.322342            0.848         1.099          0.420
# 1       0.766429            0.668         1.595          0.463
# 2       0.267192            0.947         1.417          0.547
# 3       0.142956            0.845         1.539          0.667
# 4       0.395131            0.421         1.306          0.395
# Preview of y:
# 0    Epilepsy
# 1    Epilepsy
# 2     Control
# 3         MCI
# 4         MCI
# Name: Diagnosis, dtype: object

# %% [markdown]
# # Analysis

# %% [markdown]
# 1. Pairplot (Relationship Between EEG Features)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df_clean[['AlphaPower','BetaPower','ThetaPower','GammaPower','SNR']], diag_kind='kde')
plt.show()

# %% [markdown]
# 2. Class Distribution — Diagnosis Countplot

# %%
import plotly.express as px

fig = px.bar(
    df_clean,
    x="Diagnosis",
    color="Diagnosis",
    title="Diagnosis Class Distribution",
    hover_data=df_clean.columns
)

fig.update_layout(
    width=700,
    height=500
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35a2f22b-40c8-4a01-9820-32eeed6f00b9" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35a2f22b-40c8-4a01-9820-32eeed6f00b9")) {                    Plotly.newPlot(                        "35a2f22b-40c8-4a01-9820-32eeed6f00b9",                        [{"alignmentgroup":"True","customdata":[["SUBJ_048",38,"M","Baseline",1,4.3558,0.2739,"Stimulus",37.8805297719163,32.9744235193051,37.352597716081,16.3242958553772,15.03,4.0819,0.322341723714631,0.848,1.099,0.42],["SUBJ_005",34,"F","Baseline",2,4.2919,3.3674,"Artifact",45.0803281666889,30.7719194928021,50.689475004869,21.3520778781787,11.68,0.9245,0.766428523642282,0.668,1.595,0.463],["SUBJ_029",22,"M","PostTask",8,16.6928,10.1741,"Artifact",63.5980774853143,50.3905476337998,44.5095770784229,23.9781627572207,18.18,6.5187,0.798436080002744,0.78,0.866,0.371],["SUBJ_005",34,"F","Baseline",19,-14.6806,1.0686,"Rest",47.5251588041085,32.9955968043677,46.1137340374309,23.6472189726034,10.55,-15.7492,0.387010547733145,0.68,1.356,0.487],["SUBJ_025",35,"M","Task",29,19.5796,-7.447,"Stimulus",51.7400886704644,34.6603781507051,36.3843682382459,13.8692829022646,23.03,27.0266,0.42004076434242,0.657,1.02,0.263],["SUBJ_005",34,"F","Baseline",36,-19.2127,-4.9709,"Rest",38.3065076936395,22.8441781545487,49.8387416645901,24.8851561731498,5.32,-14.2418,0.0885566433922965,0.581,2.09,0.633],["SUBJ_002",56,"F","Task",45,8.1548,2.5433,"Movement",65.246862174408,25.456069346753,40.1760504359751,15.8897444576828,5.29,5.6115,0.302642222495461,0.384,1.519,0.24],["SUBJ_017",20,"F","PostTask",47,10.5323,-5.0856,"Stimulus",61.0908234305213,33.4976380798147,47.9141873119636,17.0703315778525,8.71,15.6179,0.0491088610819599,0.539,1.389,0.275],["SUBJ_029",22,"M","PostTask",51,12.5593,-14.3226,"Blink",46.7459605765162,22.7862093391138,46.8753365003754,14.9640866754686,6.04,26.8819,0.469193444887655,0.477,1.971,0.313],["SUBJ_011",31,"M","Task",54,-7.0553,-1.89,"Artifact",49.6664626575734,38.6399930042133,41.6563713540748,20.9316077629477,12.44,-5.1653,0.759731751234032,0.763,1.051,0.413],["SUBJ_029",22,"M","PostTask",60,-21.4045,11.9247,"Stimulus",53.6353818716195,43.6345655095121,39.0555786005056,21.4028146830973,8.52,-33.3292,0.308396667723764,0.799,0.875,0.392],["SUBJ_022",42,"M","PostTask",62,-7.1027,5.9014,"Stimulus",53.6541581395513,34.9515569381517,40.207717491143,24.853803484564,20.42,-13.0041,0.327111071837208,0.64,1.118,0.455],["SUBJ_005",34,"F","Baseline",71,14.4913,-5.1166,"Artifact",50.0958325306803,29.9382955957327,46.5879175574898,15.2593234675648,15.22,19.6079,0.814278002317567,0.586,1.506,0.299],["SUBJ_022",42,"M","PostTask",83,-7.7628,-6.6061,"Rest",52.6977815959896,44.2235327773349,29.8622494901585,23.6498828247338,6.75,-1.1567,0.204588953791276,0.824,0.66,0.44],["SUBJ_048",38,"M","Baseline",86,11.3126,-14.4554,"Stimulus",58.2281194261748,32.8039113929026,49.5516794930159,26.2559604969406,16.34,25.768,0.175774514163169,0.554,1.466,0.443],["SUBJ_017",20,"F","PostTask",87,14.7558,-12.6379,"Stimulus",51.0569704033701,30.1629992104567,34.7173288703801,17.871583509953,18.35,27.3937,0.0415645238043067,0.579,1.114,0.343],["SUBJ_044",24,"F","Baseline",90,19.6208,-4.4616,"Artifact",53.8257183781158,39.3626812613703,29.045880413141,18.2427500841424,13.47,24.0824,0.896261206075855,0.718,0.72,0.333],["SUBJ_005",34,"F","Baseline",101,-17.652,-3.7516,"Stimulus",43.5906323503782,33.8360524604352,29.6626141703894,11.2653675609924,7.25,-13.9004,0.185198310380568,0.759,0.851,0.253],["SUBJ_044",24,"F","Baseline",102,-13.9561,-15.9585,"Artifact",47.4001665759369,29.1941115266225,38.7407777625028,16.3752649981178,24.59,2.0024,0.975603797891754,0.603,1.283,0.338],["SUBJ_044",24,"F","Baseline",105,-0.2768,-14.4444 ...

# %% [markdown]
# 3. Boxplot - EEG Channel1 vs Diagnosis

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df_clean, x='Diagnosis', y='EEG_Ch1')
plt.title("EEG Channel 1 Across Diagnosis")
plt.show()

# %% [markdown]
# 4. Histogram — Alpha/Beta/Theta/Gamma

# %%
df_clean[['AlphaPower','BetaPower','ThetaPower','GammaPower']].hist(figsize=(12,8))
plt.suptitle("EEG Power Distribution")
plt.show()

# %% [markdown]
# 5. KDE Plot — Fatigue Level

# %%
plt.figure(figsize=(7,5))
sns.kdeplot(df_clean['FatigueLevel'], fill=True)
plt.title("Fatigue Level Distribution")
plt.show()

# %% [markdown]
# 6. Scatter Plot — SNR vs GammaPower

# %%
import plotly.express as px

fig = px.scatter(
    df_clean,
    x="SNR",
    y="GammaPower",
    color="Diagnosis",
    hover_data=["SubjectID", "Age", "Sex", "AlphaPower", "BetaPower"],  # You can add/remove fields
    title="SNR vs GammaPower"
)

fig.update_traces(marker=dict(size=8))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b0049b15-f20e-4b02-91d2-fe56fbde2ee7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0049b15-f20e-4b02-91d2-fe56fbde2ee7")) {                    Plotly.newPlot(                        "b0049b15-f20e-4b02-91d2-fe56fbde2ee7",                        [{"customdata":[["SUBJ_048",38,"M",37.8805297719163,32.9744235193051],["SUBJ_005",34,"F",45.0803281666889,30.7719194928021],["SUBJ_029",22,"M",63.5980774853143,50.3905476337998],["SUBJ_005",34,"F",47.5251588041085,32.9955968043677],["SUBJ_025",35,"M",51.7400886704644,34.6603781507051],["SUBJ_005",34,"F",38.3065076936395,22.8441781545487],["SUBJ_002",56,"F",65.246862174408,25.456069346753],["SUBJ_017",20,"F",61.0908234305213,33.4976380798147],["SUBJ_029",22,"M",46.7459605765162,22.7862093391138],["SUBJ_011",31,"M",49.6664626575734,38.6399930042133],["SUBJ_029",22,"M",53.6353818716195,43.6345655095121],["SUBJ_022",42,"M",53.6541581395513,34.9515569381517],["SUBJ_005",34,"F",50.0958325306803,29.9382955957327],["SUBJ_022",42,"M",52.6977815959896,44.2235327773349],["SUBJ_048",38,"M",58.2281194261748,32.8039113929026],["SUBJ_017",20,"F",51.0569704033701,30.1629992104567],["SUBJ_044",24,"F",53.8257183781158,39.3626812613703],["SUBJ_005",34,"F",43.5906323503782,33.8360524604352],["SUBJ_044",24,"F",47.4001665759369,29.1941115266225],["SUBJ_044",24,"F",51.8152931807852,44.4181636609475],["SUBJ_048",38,"M",65.2727835584509,26.7015822684728],["SUBJ_014",29,"M",41.3015748625075,32.3057898942693],["SUBJ_022",42,"M",57.4902111629862,33.5531865250379],["SUBJ_048",38,"M",46.3384846537089,40.728781324207],["SUBJ_023",16,"M",52.9088191164446,27.5250595728837],["SUBJ_029",22,"M",48.2490752343852,32.6295884190764],["SUBJ_048",38,"M",73.3343261352639,24.8088044077988],["SUBJ_022",42,"M",35.1573916026003,27.3967711753738],["SUBJ_005",34,"F",59.404148945241,38.879165220933],["SUBJ_022",42,"M",51.1995612823319,38.6038361064274],["SUBJ_022",42,"M",62.7633919463407,33.9653170450369],["SUBJ_044",24,"F",66.0713560232074,30.0595186018777],["SUBJ_029",22,"M",63.9874023309323,29.4654918287004],["SUBJ_022",42,"M",47.6399472580086,27.2033500444067],["SUBJ_044",24,"F",57.6301392196404,43.6568224327635],["SUBJ_029",22,"M",53.5077762894077,34.4735196422595],["SUBJ_017",20,"F",48.5831003630896,30.7876827582567],["SUBJ_014",29,"M",59.4846881059984,14.7987415456671],["SUBJ_014",29,"M",58.3940101945255,43.6151954958631],["SUBJ_022",42,"M",38.8521092824547,31.6013771407],["SUBJ_044",24,"F",42.3437627065109,21.0580041568821],["SUBJ_002",56,"F",68.0446573056771,28.1501897001886],["SUBJ_017",20,"F",56.8222250466845,27.8263573964847],["SUBJ_022",42,"M",45.2682410745963,30.0870181213274],["SUBJ_014",29,"M",51.477763474657,28.0040532622191],["SUBJ_011",31,"M",64.4037549616087,49.9971128439471],["SUBJ_029",22,"M",64.4097343462061,36.492085760055],["SUBJ_029",22,"M",49.0731885001345,38.4585694313599],["SUBJ_044",24,"F",69.8689808775513,23.3377906294928],["SUBJ_022",42,"M",64.6287924117284,34.1974488651085],["SUBJ_017",20,"F",54.4531573629676,23.5645656120501],["SUBJ_029",22,"M",68.0080041940333,33.0564958841475],["SUBJ_044",24,"F",51.6291944769535,23.4097821831521],["SUBJ_029",22,"M",52.7823954049494,17.5183837935937],["SUBJ_048",38,"M",53.3779012204288,28.3588533010828],["SUBJ_048",38,"M",57.3248441274867,32.2378040811086],["SUBJ_014",29,"M",75.4505727238808,27.2986691870536],["SUBJ_014",29,"M",53.3511251973913,33.1495152719645],["SUBJ_025",35,"M",53.9388456315866,21.7518442443264],["SUBJ_005",34,"F",64.6888105260378,48.8138527120514],["SUBJ_044",24,"F",57.7467390837539,28.1497562983454],["SUBJ_017",20,"F",71.6192956271001,25.8029777197002],["SUBJ_044",24,"F",36.5526302320838,24.2659378493807],["SUBJ_023",16,"M",27.0319005 ...

# %% [markdown]
# 7. Line Plot — Engagement Index Over Samples

# %%
plt.figure(figsize=(10,5))
plt.plot(df_clean['EngagementIndex'])
plt.title("Engagement Index Over Time")
plt.xlabel("Sample")
plt.ylabel("Engagement Index")
plt.show()

# %% [markdown]
# 8. Interactive Scatter (Swarm-style) — CognitiveLoad by Sex

# %%
import plotly.express as px
import numpy as np

# Add small jitter so points don’t overlap
df_clean['Sex_Jitter'] = df_clean['Sex'].map({'M':0, 'F':1}) + (np.random.rand(len(df_clean)) - 0.5) * 0.15

fig = px.scatter(
    df_clean,
    x="Sex_Jitter",
    y="CognitiveLoad",
    color="Sex",
    hover_data=["SubjectID", "Age", "Diagnosis", "AlphaPower", "BetaPower"],
    title="Cognitive Load Distribution by Sex (Interactive Scatter with Hover)"
)

# Fix x-axis labels
fig.update_xaxes(
    tickvals=[0,1],
    ticktext=["M","F"],
    title="Sex"
)

fig.update_traces(marker=dict(size=8, opacity=0.7))
fig.update_layout(height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eeaf80d7-61a9-48ba-a8d2-e2376e7ef897" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eeaf80d7-61a9-48ba-a8d2-e2376e7ef897")) {                    Plotly.newPlot(                        "eeaf80d7-61a9-48ba-a8d2-e2376e7ef897",                        [{"customdata":[["SUBJ_048",38,"Epilepsy",37.8805297719163,32.9744235193051],["SUBJ_026",27,"Control",41.2635390700505,40.0214177333167],["SUBJ_004",27,"MCI",30.8563448610823,26.93176405507],["SUBJ_040",58,"Control",47.8018644668313,28.1656324725509],["SUBJ_029",22,"Epilepsy",63.5980774853143,50.3905476337998],["SUBJ_026",27,"Control",48.5594203917878,10.4794727838026],["SUBJ_047",29,"MCI",56.5824056656519,16.8778744024348],["SUBJ_040",58,"Control",62.6041879395337,17.618392305228],["SUBJ_045",49,"MCI",41.0968146474581,22.4297457650343],["SUBJ_001",38,"Control",41.0885046771239,14.6535165216113],["SUBJ_045",49,"MCI",46.6790129478321,31.4748625769564],["SUBJ_025",35,"Epilepsy",51.7400886704644,34.6603781507051],["SUBJ_001",38,"Control",53.0786609510465,40.750773738186],["SUBJ_035",47,"Control",64.1132859348024,34.064210425781],["SUBJ_010",21,"MCI",38.5292890748958,22.2152373419927],["SUBJ_047",29,"MCI",58.1441684865558,35.3338346016484],["SUBJ_010",21,"MCI",46.7438603251165,30.4368973682357],["SUBJ_004",27,"MCI",46.8081991597269,32.0832426278622],["SUBJ_001",38,"Control",47.4193226251196,31.5400285287289],["SUBJ_032",37,"Control",33.1193007386965,34.4503147919807],["SUBJ_030",39,"MCI",30.7470762891683,24.9663511694021],["SUBJ_045",49,"MCI",57.9207958111221,14.2157679756746],["SUBJ_029",22,"Epilepsy",46.7459605765162,22.7862093391138],["SUBJ_011",31,"Epilepsy",49.6664626575734,38.6399930042133],["SUBJ_001",38,"Control",41.6586995252558,30.0906191140201],["SUBJ_029",22,"Epilepsy",53.6353818716195,43.6345655095121],["SUBJ_022",42,"Epilepsy",53.6541581395513,34.9515569381517],["SUBJ_034",39,"Control",51.1572874366628,25.1092981329144],["SUBJ_004",27,"MCI",38.4467244992073,26.6875330720897],["SUBJ_028",25,"Control",46.6591111582162,32.3703197307761],["SUBJ_034",39,"Control",61.819471830183,39.7834756677493],["SUBJ_028",25,"Control",45.2733689579876,11.3227406223069],["SUBJ_034",39,"Control",54.5151538545893,39.3905375775162],["SUBJ_038",25,"Control",57.1193062683695,24.4438527405718],["SUBJ_010",21,"MCI",29.0287076189133,33.15007085751],["SUBJ_030",39,"MCI",43.8011730208573,27.6929589723654],["SUBJ_032",37,"Control",51.2884588996027,28.7229916674602],["SUBJ_003",37,"MCI",47.620151016214,44.3500828084728],["SUBJ_019",31,"MCI",51.961815152279,47.7865845366951],["SUBJ_022",42,"Epilepsy",52.6977815959896,44.2235327773349],["SUBJ_004",27,"MCI",55.5558801737152,29.3243457423261],["SUBJ_048",38,"Epilepsy",58.2281194261748,32.8039113929026],["SUBJ_030",39,"MCI",69.4505560886459,29.2724563099519],["SUBJ_010",21,"MCI",49.1055103152425,14.4658567637422],["SUBJ_004",27,"MCI",65.2167755680977,29.0616948366926],["SUBJ_047",29,"MCI",65.7627176966775,18.8295507434822],["SUBJ_021",28,"MCI",47.0934395503575,33.1771686870934],["SUBJ_048",38,"Epilepsy",65.2727835584509,26.7015822684728],["SUBJ_014",29,"Epilepsy",41.3015748625075,32.3057898942693],["SUBJ_040",58,"Control",54.0948009362992,21.4556033459293],["SUBJ_004",27,"MCI",62.0070504071589,33.0460009206074],["SUBJ_030",39,"MCI",41.9679473147798,35.3977246418151],["SUBJ_030",39,"MCI",46.119115025998,35.6483468014906],["SUBJ_022",42,"Epilepsy",57.4902111629862,33.5531865250379],["SUBJ_045",49,"MCI",55.9497377566556,36.3633153652663],["SUBJ_028",25,"Control",55.6063226627809,30.6200121255829],["SUBJ_048",38,"Epilepsy",46.3384846537089,40.728781324207],["SUBJ_030",39,"MCI",60.1172340967254,31.6046751107057],["SUBJ_001",38,"Control",40.413679387232,32. ...

# %% [markdown]
# 9. Joint Plot — Alpha vs Beta Power

# %%
sns.jointplot(data=df_clean, x='AlphaPower', y='BetaPower', kind='hex')
plt.show()

# %% [markdown]
# 10. Correlation Matrix of Power Bands

# %%
powers = df_clean[['AlphaPower','BetaPower','ThetaPower','GammaPower']]
plt.figure(figsize=(8,6))
sns.heatmap(powers.corr(), annot=True, cmap="coolwarm")
plt.title("Power Band Correlation")
plt.show()

# %% [markdown]
# 11.PIE CHART FOR SEX DISTRIBUTION

# %%
plt.figure(figsize=(7, 7))
df["Sex"].value_counts().plot.pie(autopct='%1.1f%%', shadow=True)
plt.title("Sex Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# 12.PIE CHART FOR DIAGNOSIS

# %%
plt.figure(figsize=(7, 7))
df["Diagnosis"].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Diagnosis Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# 13.BAR CHART - SESSION COUNT

# %%
sns.countplot(data=df, x="Session", palette="viridis")
plt.title("Session Count Distribution")
plt.show()

# %% [markdown]
# 14.EEG CHANNEL DISTRIBUTIONS

# %%
sns.histplot(df["EEG_Ch1"], kde=True)
plt.title("EEG Channel 1 Distribution")
plt.show()

sns.histplot(df["EEG_Ch2"], kde=True)
plt.title("EEG Channel 2 Distribution")
plt.show()
